# %%
# %run ./imports.ipynb
# %run ./tools_fun.ipynb

# %%
def handle_tool_calls(message):
    responses = []
    for tool_call in message.tool_calls:
        args = json.loads(tool_call.function.arguments)
        if tool_call.function.name == "get_ticket_price":
            content = get_ticket_price(args.get('destination_city'))
        elif tool_call.function.name == "set_ticket_price":
            content = set_ticket_price(args.get("city"), args.get("price"))
        elif tool_call.function.name == "book_flight":
            content = book_flight(args.get("passenger_name"), args.get("destination_city"))
        elif tool_call.function.name == "get_booking_details":
            content = get_booking_details(args.get("passenger_name"))
        else:
            content = "Error: Tool not found."
        
        responses.append({
            "role": "tool",
            "content": content,
            "tool_call_id": tool_call.id
        })
    return responses
